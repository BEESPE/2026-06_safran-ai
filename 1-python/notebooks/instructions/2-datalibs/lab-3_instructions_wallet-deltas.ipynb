# %% [markdown]
# Load the 2 inventory CSV files into pandas DataFrames.

# %%
# Your code here

# %% [markdown]
# Explore these files to try to understand their structure.

# %%
# Your code here

# %% [markdown]
# Determine if there are any duplicate rows.

# %%
# Your code here

# %% [markdown]
# Aggregate multiple rows associated with the same (portfolio, asset) pair using an appropriate aggregation function.

# %%
# Your code here

# %% [markdown]
# Write a small script to calculate the changes of each asset in each portfolio whenever there is a non-zero change. Store the results in a DataFrame.

# %%
# Your code here

# %% [markdown]
# Visualize the distribution of non-zero changes.

# %%
# Your code here

# %% [markdown]
# Export the DataFrame of changes to a CSV file.

# %%
# Your code here

# %% [markdown]
# ### Visualisations

# %% [markdown]
# Visualize the distribution of non-zero variations.

# %%
# Your code here

# %% [markdown]
# Visualize the composition of portfolio 111111.

# %%
# Your code here

# %% [markdown]
# Group assets representing less than 2% into an “others” category.

# %%
# Your code here

# %% [markdown]
# If there are none, add borders between the pie chart slices. Export the chart as an image file.

# %%
# Your code here
